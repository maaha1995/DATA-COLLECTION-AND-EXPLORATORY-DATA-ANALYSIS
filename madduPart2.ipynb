# %%
##Mahalakshmi Padma Sri Harsha Maddu - mmaddu - 50246769
## Parikshit Sunil Deshmukh - 50247649

# %%
library(ggplot2)
library(reshape2)

positive_tested <-read.csv("positive_tested.csv")
week <- as.factor(positive_tested$Week)
options(repr.plot.width=7, repr.plot.height=5)
mdat <- melt(positive_tested,measure.vars=c("A.Subtyping.not.performed.","A.H3N2v.","A..H1N1.pdm09","A.H3.","A.unable.to.sub.type.","B","BVIC","BYAM"))
plot1 <- ggplot(mdat, aes(x=as.factor(Week), y=value, fill = variable))+ 
theme_bw() + 
geom_bar(position="stack", stat="identity", colour="black") + 
theme(axis.text.x = element_text(angle = 45, hjust = 1)) +
ggtitle("Influenza Positive Tests Reported to CDC by U.S. \nPublic Health Laboratory 2017-2018 Season") +
xlab("Week") + 
ylab("Number of Positive Specimens")+ 
scale_x_discrete(expand = c(0,0)) + 
scale_y_continuous(expand=c(0,0)) +
theme(axis.line = element_line(colour = "black"),
panel.grid.major = element_blank(),
panel.grid.minor = element_blank(),
panel.border = element_blank(),
panel.background = element_blank())+
scale_fill_manual( values=c("yellow", "purple", "orange","red","blue","darkgreen","yellow","lightgreen"), 
breaks=c("A.Subtyping.not.performed.","A.H3N2v.", "A..H1N1.pdm09","A.H3.","A.unable.to.sub.type.","B","BVIC","BYAM"),
labels=c("A(subtyping not performed)","A.H3N2v", "A(H1N1)pdm09","A(H3N2)","A.unable.to.sub.type.","B(lineage not performed)","B(Victoria Lineage)","B(Yamagata Lineage)"))

plot1
# Out:
# plot without title

# %%
library(reshape2)
library(ggplot2)

Pediatric_Deaths <- read.csv("Pediatric_Deaths.csv", header=T)
data_frame <- melt(Pediatric_Deaths[,c('WEEK.NUMBER','CURRENT.WEEK.DEATHS','PREVIOUS.WEEKS.DEATHS')],id.vars =1 )
aggregate_dataframe <-aggregate(cbind(Pediatric_Deaths$'CURRENT.WEEK.DEATHS', Pediatric_Deaths$'PREVIOUS.WEEKS.DEATHS') ~ Pediatric_Deaths$'SEASON', data=Pediatric_Deaths, FUN=sum)
sum_of_rows<-rowSums(aggregate_dataframe[,c("V1", "V2")])

options(repr.plot.width=22, repr.plot.height=10)
plot2 <- ggplot(data=data_frame,aes(x=WEEK.NUMBER))+
geom_bar(aes(y=value,fill=variable),stat="Identity",width=0.9, colour="black",position = "stack")+ 
theme_minimal(base_size=6)+theme_bw()+theme(axis.text=element_text(size=12),
        axis.title=element_text(size=24,face="bold")) +
theme(plot.title = element_text(size = 100, face = "bold"))+ 
scale_y_continuous(limits=c(0,25)) +
theme(axis.text.x=element_text(color=c("black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black","transparent","transparent","transparent","transparent","transparent","black")))+
theme(axis.text.x = element_text(angle = 90))+
theme(axis.text=element_text(size=18))+
scale_fill_manual(values=c('skyblue','darkgreen'))+
##scale_x_discrete(breaks =c( "2014-40", "2014-46", "2014-52", "2015-05", "2015-11", "2015-17", "2015-23", "2015-29", "2015-35", "2015-41", "2015-47", "2016-01", "2016-07", "2016-13", "2016-19", "2016-25", "2016-31", "2016-37", "2016-43", "2016-49", "2017-03", "2017-09", "2017-15","2017-21", "2017-27", "2017-33", "2017-39", "2017-45", "2017-51", "2018-05", "2018-11", "2018-17", "2018-23", "2018-29", "2018-35", "2014-41", "2014-47", "2014-53", "2015-06", "2015-12", "2015-18", "2015-24", "2015-30", "2015-36", "2015-42", "2015-48", "2016-02", "2016-08", "2016-14", "2016-20", "2016-26", "2016-32", "2016-38", "2016-44", "2016-50", "2017-04", "2017-10","2017-16", "2017-22", "2017-28","2017-34", "2017-40", "2017-46", "2017-52", "2018-06", "2018-12","2018-18","2018-24","2018-30","2018-36"))+
xlab('Week of Death')+
ylab('Number of deaths')+
annotate("text", x = 25,  y=20.5, label= paste("2014-2015, \n Number of Deaths \n Reported = ", sum_of_rows[1]), size = 8) + 
annotate("text", x = 75,  y=20.5, label = paste("2015-2016, \n Number of Deaths \n Reported  = ", sum_of_rows[2]), size = 8)+ 
annotate("text", x = 130, y=20.5, label = paste("2016-2017, \n Number of Deaths \n Reported  = ", sum_of_rows[3]), size = 8)+ 
annotate("text", x = 175, y=20.5, label = paste("2017-2018, \n Number of Deaths \n Reported  = ", sum_of_rows[4]), size = 8)+
ggtitle('                                         Number of Influenza-Associcated Pediatric Deaths\n                                            by Week of Death:2014-2015 Season to Present')+
theme(plot.title = element_text(size = 35, face = "bold"))+theme(legend.title = element_blank()) + theme(legend.text=element_text(size=18)) + theme(legend.position="bottom") +
theme(axis.line = element_line(colour = "black"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    panel.border = element_blank(),
    panel.background = element_blank()) 

plot2
# Out:
# plot without title

# %%
library(ggplot2)

national_summary <- read.csv("national_summary.csv", header = TRUE, sep = ",", stringsAsFactors = TRUE)
options(repr.plot.width=5, repr.plot.height=7)

plot3 <- ggplot(national_summary, aes(x = as.factor(national_summary$Week))) +
geom_bar(aes(y=national_summary$Total_A + national_summary$Total_B),stat = "identity", fill = "yellow", color = "black")+
geom_bar(aes(y=national_summary$Total_B),stat = "identity", fill = "darkgreen", color = "black")+
geom_line(aes(y=X..Positive*20000/32, group =1), colour= "black", size=0.8)+
geom_line(aes(y=national_summary$Percent.Positive.A*20000/32, group =1), colour= "red", linetype = 2, size=0.5)+
geom_line(aes(y=(national_summary$Percent.Positive.A-0.3)*20000/32, group =1), colour= "black", linetype = 2, size=0.5, alpha="0.4")+
geom_line(aes(y=national_summary$Percent.Positive.B*20000/32, group =1), colour= "blue", linetype = "dotted", size=0.5)+
geom_line(aes(y=(national_summary$Percent.Positive.B-0.2)*20000/32, group =1), colour= "black", linetype = "dotted", size=0.5, alpha="0.4")+
labs(title="                   Influenza Positive Tests \n Reported to CDC by U.S. Clinical Laboratories,\n        National Summary, 2017-2018 Season\n\n\n", size = 1)+
xlab("Week") +
scale_fill_manual("legend", values = c("Percen.Positive.A"="yellow"))+
scale_y_continuous(expand = c(0,0),name="Number of Positive Specimens",sec.axis = sec_axis(~ . * 32 / 20000, name = "Percent Positive", breaks=seq(0,32, by=2)), breaks=seq(0,20000, by=2000))+
scale_x_discrete(expand = c(0,0), breaks=seq(201740,201820, by=2))+
coord_cartesian(ylim = c(0, 20000))+
theme_classic()+

theme(axis.line = element_line(colour = "black"),axis.text.x = element_text( color="black",angle= 90),
    legend.position = "right",legend.title= element_text("Legends"),
    panel.grid.major = element_blank(),
    panel.grid.minor = element_blank(),
    panel.border = element_blank(),
    panel.background = element_blank()) 


plot3
# Out:
# plot without title

# %%
library(ggplot2)
library(fiftystater)
library(dplyr)


DataForHeatMap <- read.csv("DataForHeatMap.csv", header = TRUE, sep = ",", stringsAsFactors = TRUE)[,1:5]

options(repr.plot.width=10, repr.plot.height=7)
data <- dplyr::select(DataForHeatMap, 1, 4:5)
levels(data$STATENAME) <- tolower(levels(data$STATENAME))
data_frame <- data[c(1:8, 10:51),]

plot4 <- ggplot(data_frame, aes(map_id = data_frame$STATENAME)) + 
geom_map(aes(fill = data_frame$ACTIVITY.LEVEL), map = fifty_states) + 
expand_limits(x = fifty_states$long, y = fifty_states$lat) +
coord_map() + 
scale_x_continuous(breaks = NULL) + 
scale_y_continuous(breaks = NULL) +
labs(x = "", y = "") +
theme(legend.position = "right", panel.background = element_blank()) + 
ggtitle("2017-18 Influenza Season Week 8 ending Feb 24, 2018") +
scale_fill_manual("Heat Level", values=c("darkgoldenrod1", "red3", "green2","green","olivedrab1","gold1","chocolate2","yellow", "orangered", "green4"))


plot4
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# plot without title

# %%
library(ggplot2)
#install.packages("ggrepel")
library(ggrepel)
library(ggpubr)
dt<-read.csv("PieChart.csv", header=T)
specs<-read.csv("SpecimenFlu.csv", header=T)

#dt
dt$X..of..Sub.type.Total <- sub("^$", 0, dt$X..of..Sub.type.Total)
dt$X..of..Sub.type.Total <- as.numeric(sub("%","",dt$X..of..Sub.type.Total))
dt$X..of..Sub.type.Total[is.na(dt$X..of..Sub.type.Total)]<-0
dt$X..of..Sub.type.Total<- as.numeric(dt$X..of..Sub.type.Total)

vict<- subset(dt, dt$X.Sub.type=='B/Victoria')
yama <- subset(dt, dt$X.Sub.type=='B/Yamagata')
h1<- subset(dt, dt$X.Sub.type=='H1pdm09')
h3<- subset(dt, dt$X.Sub.type=='H3')


blank_theme <- theme_minimal()+
  theme(
    axis.title.x = element_blank(),
    axis.title.y = element_blank(),
    axis.text = element_blank(),
    panel.grid=element_blank(),
    axis.ticks = element_blank()
  )

y.breaks <- cumsum(vict$X..of..Sub.type.Total) - vict$X..of..Sub.type.Total/2
#y.breaks



vict$col <- c("A","B")
pVict<-ggplot(vict , aes(x="", y=vict$X..of..Sub.type.Total , fill=vict$col)) + geom_bar(color="black",width = 1,  stat = "identity") +
  coord_polar("y", start =0) + 
  geom_label_repel(aes(label = paste(vict$Genetic_Group, '\n', vict$Number, '\n', vict$X..of..Sub.type.Total, "%" )), point.padding = 0.25,
                   box.padding = 0.25,
                   nudge_y = 0.1, show.legend =FALSE)+labs(title="Influenza B(Yagamata)") +
  blank_theme + theme(legend.position="none", plot.margin = unit(c(1, 1, 1, 1), "lines"),  panel.border = element_rect(colour = "black", fill=NA, size=1)) +
  scale_fill_manual("legend", values = c("A" = "#b3ff99", "B" = "#f2ffe6"))
#scale_y_continuous(breaks = cumsum(vict$X..of..Sub.type.Total) - vict$X..of..Sub.type.Total/2 , labels = paste(vict$Genetic_Group, '\n', vict$Number, '\n', vict$X..of..Sub.type.Total, "%" ))

#pVict

yama$col<-c("A","B","C")
pYama<-ggplot(yama , aes(x="", y=yama$X..of..Sub.type.Total , fill=yama$col)) + geom_bar(color="black", width = 1, stat = "identity") +
  coord_polar("y", start =0) + 
  geom_label_repel(aes(label = paste(yama$Genetic_Group, '\n', yama$Number, '\n', yama$X..of..Sub.type.Total, "%" )), point.padding = 0.25,
                   box.padding = 0.25,
                   nudge_y = 0.1)+ ggtitle("Influenza B(Victoria)")+
  blank_theme + theme(legend.position="none", plot.margin = unit(c(1, 1, 1, 1), "lines"),  panel.border = element_rect(colour = "black", fill=NA, size=1))+
  scale_fill_manual("legend", values = c("A" = "#33cc33", "B" = "yellow", "C" ="yellow"))
#scale_y_continuous(breaks = cumsum(yama$X..of..Sub.type.Total) - yama$X..of..Sub.type.Total/2 , labels = paste(yama$Genetic_Group, '\n', yama$Number, '\n', yama$X..of..Sub.type.Total, "%" ))
#pYama

h1$col<-c("A","B","C")
pH1<-ggplot(h1  , aes(x="", y=h1$X..of..Sub.type.Total , fill=h1$col)) + geom_bar(color="black",width = 1, stat = "identity") +
  coord_polar("y", start =0) + 
  geom_label_repel(aes(label = paste(h1$Genetic_Group, '\n', h1$Number, '\n', h1$X..of..Sub.type.Total, "%" )), point.padding = 0.25,
                   box.padding = 0.25,
                   nudge_y = 0.1, show.legend =FALSE)+ ggtitle("Influenza A(H1N1)pdm09")+
  blank_theme+ theme(legend.position="none", plot.margin = unit(c(1, 1, 1, 1), "lines"),  panel.border = element_rect(colour = "black", fill=NA, size=1))+
  scale_fill_manual("legend", values = c("A" = "#ffb84d", "B" = "yellow", "C" ="yellow"))
#scale_y_continuous(breaks = cumsum(h1$X..of..Sub.type.Total) - h1$X..of..Sub.type.Total/2 , labels = paste(h1$Genetic_Group, '\n', h1$Number, '\n', h1$X..of..Sub.type.Total, "%" ))
#pH1

h3$col <- c("A","B","C","D","E")
pH3<-ggplot(h3 , aes(x="", y=h3$X..of..Sub.type.Total , fill=h3$col)) + geom_bar(color="black",width = 1, stat = "identity") +
  coord_polar("y", start =0) + 
  geom_label_repel(aes(label = paste(h3$Genetic_Group, '\n', h3$Number, '\n', h3$X..of..Sub.type.Total, "%" )),  point.padding = 0.25,
                   box.padding = 0.25,
                   nudge_y = 0.1, show.legend =FALSE)+ ggtitle("Influenza A(H3N2)")+
  blank_theme + theme(legend.position="none", plot.margin = unit(c(1, 1, 1, 1), "lines"),  panel.border = element_rect(colour = "black", fill=NA, size=1))+
  scale_fill_manual("legend", values = c("A" = "#ff0000", "B"="#ff8080", "C"="#ffe6e6"  ,"D" = "yellow", "E" ="yellow"))
#scale_y_continuous(breaks = cumsum(h3$X..of..Sub.type.Total) - h3$X..of..Sub.type.Total/2 , labels = paste(h3$Genetic_Group, '\n', h3$Number, '\n', h3$X..of..Sub.type.Total, "%" ))
#pH3


specs$newCol <- gsub(",","", specs$Data.Cumulative.since.October.1..2017..Week.40.)
specs$newCol<- gsub("\\s+\\([0-9][0-9].[0-9]%)|\\s+\\([0-9].[0-9]%)","",specs$newCol)
specs$newCol <- as.numeric(specs$newCol)


newSpecs <- specs[c(5,6,7,9,10,11), c(1,3,4)]
newSpecs$col <- c("Influenza A(H3N2)","Influenza A(H1N1)pdm09","Influenza A(subtype Unknown)","Influenza B(Victoria)","Influenza B(Yagamata)","Influenza B (Lineage not determined)")
#newSpecs



pSpecs<-ggplot(newSpecs , aes(x=factor(1), y=newSpecs$newCol , fill=factor(newSpecs$col))) + geom_bar(color="black",width = 1, stat = "identity") +
  coord_polar("y", start =0) + 
  geom_label_repel(aes(label = newSpecs$newCol), show.legend =FALSE  )+ 
  blank_theme + theme( legend.position = "bottom", legend.title = element_blank(), plot.margin = unit(c(1, 1, 1, 1), "lines"),  panel.border = element_blank())+
  guides(fill=guide_legend(ncol=1))+ ggtitle("Influenza Positive specimens")+
  scale_fill_manual("legend", values = c("Influenza A(H3N2)" = "#ffb84d", "Influenza A(H1N1)pdm09" = "#ff0000", "Influenza A(subtype Unknown)" = "#ffff99", "Influenza B(Victoria)"="#33cc33", "Influenza B(Yagamata)"="#b3ff99", "Influenza B (Lineage not determined)"="#006600"))
# scale_y_continuous(breaks =  cumsum(newSpecs$newCol/2) - newSpecs$newCol, labels = newSpecs$newCol)
#scale_y_continuous(breaks = cumsum(h3$X..of..Sub.type.Total) - h3$X..of..Sub.type.Total/2 , labels = paste(h3$Genetic_Group, '\n', h3$Number, '\n', h3$X..of..Sub.type.Total, "%" ))
#pSpecs

comb2<-ggarrange(pSpecs,                                                 # First row with scatter plot
                 ggarrange( pH3, pH1, pVict, pYama, nrow=2, ncol = 2 ,  labels = "Sequence Results by Gentic HA Clade/Subclade of Specimens" ), # Second row with box and dot plots
                 ncol  = 2
                 # Labels of the scatter plot
) 
comb2
# Out:
# plot without title
